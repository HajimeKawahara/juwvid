# %% [markdown]
# # Demonstration on the polynomial Wigner Ville with the non-uniform FFT

# %%
using PyPlot
import DSP

# %%
include("../juwvid.jl")
# Out:
# juwvid

# %%
# multi component data
nsample=512
t,x=sampledata.genmultifm623x(nsample);
PyPlot.plot(t,x)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcf68e23b50>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7fcf6918b690>

# %% [markdown]
# ### polynomial WV with FFT

# %%
# the resolution is poor  
trfpo=polywv.tfrpowv(x,NaN,NaN,NaN,2,2);
a=juwplot.wtfrshow(abs(trfpo),t[2]-t[1],t[1],t[end],NaN,NaN,0.7*3,"Spectral")
PyPlot.ylim(0,40)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcf64e33090>)
# Use fft.
# (0,40)

# %%
nnufft=1024
nsample=length(t)
js,je=juwutils.frequency_to_index([5.0,30.0], t[2]-t[1], nsample,nnufft)
# Out:
# 2-element Array{Float64,1}:
#   21.0391
#  121.235

# %% [markdown]
# ### with NuFFT

# %%
# now, the resolution is fine  
fin=collect(linspace(js,je,nnufft));
trfpo=polywv.tfrpowv(x,NaN,NaN,fin,2,2);
a=juwplot.wtfrshow(abs(trfpo),t[2]-t[1],t[1],t[end],NaN,NaN,0.7,"Spectral")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcf647a4190>)
# Use nufft.
# PyObject <matplotlib.image.AxesImage object at 0x7fcf64c2d090>
