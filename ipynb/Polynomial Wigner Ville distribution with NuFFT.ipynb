# %% [markdown]
# # Demonstration on the polynomial Wigner Ville with the non-uniform FFT
# last update: 2/15 (2018)

# %%
using PyPlot
import DSP

# %%
include("../juwvid.jl")
# Out:
# juwvid

# %%
# multi component data
nsample=512
t,x=sampledata.genmultifm623x(nsample);
PyPlot.plot(t,x)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9cab825ba8>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x7f9ca74dfe10>

# %% [markdown]
# ### polynomial WV with FFT

# %%
# the resolution is poor  
trfpo=polywv.tfrpowv(x,NaN,NaN,NaN,2,2);
a=juwplot.wtfrshow(abs.(trfpo),t[2]-t[1],t[1],t[end],NaN,NaN,0.7*3)
PyPlot.ylim(0,40)
# Out:
# Single S-method
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9ca7492be0>)
# Use fft.
# (0, 40)

# %%
nnufft=1024
nsample=length(t)
js,je=juwutils.frequency_to_index([5.0,30.0], t[2]-t[1], nsample,nnufft)
# Out:
# 2-element Array{Float64,1}:
#   20.0391
#  120.235

# %% [markdown]
# ### with NuFFT

# %%
# now, the resolution is fine  
fin=collect(linspace(js,je,nnufft));
trfpo=polywv.tfrpowv(x,NaN,NaN,fin,2,2);
a=juwplot.wtfrshow(abs.(trfpo),t[2]-t[1],t[1],t[end],NaN,NaN,0.7)
# Out:
# Single S-method
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f9ca680ae80>)
# Use nufft.
# PyObject <matplotlib.image.AxesImage object at 0x7f9ca66ee240>
